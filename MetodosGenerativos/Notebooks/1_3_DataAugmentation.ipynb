# %% [markdown]
# # Imports

# %%
import os, glob, requests,  statistics
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
import numpy as np

from tensorflow.keras import layers, Sequential, models, losses, utils, Model
from tensorflow import image
from tensorflow.keras.datasets import cifar10

# %% [markdown]
# # Descargar imagen desde un url

# %%
def download_file(url, name):
    img_data = requests.get(url).content
    with open(name, 'wb') as handler:
        handler.write(img_data)

# %%
download_file("https://drive.google.com/uc?id=1xqWAcHjIXzCBPhMZugATiYWnbgl3mx_r", "Parrot.png")

# %%
import cv2
img_parrot = cv2.imread('/content/Parrot.png')
img_parrot = img_parrot / 255

# %% [markdown]
# # Transformaciones

# %% [markdown]
# ## Crop

# %%
transform = Sequential([
  layers.RandomCrop(512,512)
])
augmented_parrot = transform(img_parrot)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].imshow(img_parrot)
ax[1].imshow(augmented_parrot)

plt.show()

# %% [markdown]
# ## Horizontal flip

# %%
transform = Sequential([
  layers.RandomFlip('horizontal')
])
augmented_parrot = transform(img_parrot)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].imshow(img_parrot)
ax[1].imshow(augmented_parrot)

plt.show()

# %% [markdown]
# ## Vertical flip

# %%
transform = Sequential([
  layers.RandomFlip('vertical')
])
augmented_parrot = transform(img_parrot)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].imshow(img_parrot)
ax[1].imshow(augmented_parrot)

plt.show()

# %% [markdown]
# ## Rotation

# %%
transform = Sequential([
  layers.RandomRotation(factor=(-0.2, 0.2))
])
augmented_parrot = transform(img_parrot)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].imshow(img_parrot)
ax[1].imshow(augmented_parrot)

plt.show()

# %% [markdown]
# ## Translation

# %%
transform = Sequential([
  layers.RandomTranslation(height_factor=(-0.2, 0.2),
                           width_factor=(-0.2, 0.2))
])
augmented_parrot = transform(img_parrot)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].imshow(img_parrot)
ax[1].imshow(augmented_parrot)

plt.show()

# %% [markdown]
# ## Brightness changes

# %%
augmented_parrot = image.stateless_random_brightness(img_parrot, max_delta=0.2, seed=(1,1))

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].imshow(img_parrot)
ax[1].imshow(augmented_parrot)

plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Contrast changes

# %%
transform = Sequential([
  layers.RandomContrast(factor=0.7)
])
augmented_parrot = transform(img_parrot)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].imshow(img_parrot)
ax[1].imshow(augmented_parrot)

plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Hue changes

# %%
augmented_parrot = image.stateless_random_hue(img_parrot, max_delta=0.2, seed=(1,1))

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].imshow(img_parrot)
ax[1].imshow(augmented_parrot)

plt.show()

# %% [markdown]
# ## Quality changes

# %%
augmented_parrot = image.stateless_random_jpeg_quality(img_parrot,
                                                       min_jpeg_quality=5,
                                                       max_jpeg_quality=15,
                                                       seed=(1,1))

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].imshow(img_parrot)
ax[1].imshow(augmented_parrot)

plt.show()

# %% [markdown]
# # Prueba de entrenamiento con Data Augmentation

# %%
(X_train, y_train), (X_test, y_test) =  cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
# one hot encode outputs
y_train = LabelBinarizer().fit_transform(y_train)
y_test = LabelBinarizer().fit_transform(y_test)
num_classes = y_test.shape[1]

# %%
input = layers.Input(shape=(32, 32, 3))

# Data augmentation preprocessing layers
# More layers at https://keras.io/api/layers/preprocessing_layers/image_augmentation/
x = layers.RandomFlip("horizontal")(input)
x = layers.RandomRotation(0.1)(x)
x = layers.RandomZoom(0.1)(x)

# Keras model
x = layers.Conv2D(16, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(64, (3, 3), activation='relu')(x)
x = layers.Flatten()(x)
x = layers.Dense(512, activation='relu')(x)
output = layers.Dense(num_classes, activation='sigmoid')(x)

model = Model(input, output)

model.compile(optimizer='adam', loss=losses.CategoricalCrossentropy(), metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  random_flip_2 (RandomFlip)  (None, 32, 32, 3)         0
#
#  random_rotation_1 (RandomR  (None, 32, 32, 3)         0
#  otation)
#
#  random_zoom (RandomZoom)    (None, 32, 32, 3)         0
#
#  conv2d (Conv2D)             (None, 30, 30, 16)        448
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 32)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          18496
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 512)               524800
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 553514 (2.11 MB)
# Trainable params: 553514 (2.11 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Manually loading the dataset
history = model.fit(X_train, y_train, validation_split = 0.2, batch_size=512, epochs = 50)
# Out:
# Epoch 1/50
# 79/79 [==============================] - 12s 22ms/step - loss: 4.1175 - accuracy: 0.2535 - val_loss: 1.8137 - val_accuracy: 0.3495
# Epoch 2/50
# 79/79 [==============================] - 1s 11ms/step - loss: 1.6980 - accuracy: 0.3855 - val_loss: 1.6090 - val_accuracy: 0.4182
# Epoch 3/50
# 79/79 [==============================] - 1s 10ms/step - loss: 1.5833 - accuracy: 0.4307 - val_loss: 1.6288 - val_accuracy: 0.4299
# Epoch 4/50
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5134 - accuracy: 0.4583 - val_loss: 1.5849 - val_accuracy: 0.4424
# Epoch 5/50
# 79/79 [==============================] - 1s 11ms/step - loss: 1.4799 - accuracy: 0.4667 - val_loss: 1.4631 - val_accuracy: 0.4821
# Epoch 6/50
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4273 - accuracy: 0.4906 - val_loss: 1.4735 - val_accuracy: 0.4825
# Epoch 7/50
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3857 - accuracy: 0.5036 - val_loss: 1.3812 - val_accuracy: 0.5088
# Epoch 8/50
# 79/79 [==============================] - 1s 10ms/step - loss: 1.3604 - accuracy: 0.5126 - val_loss: 1.4417 - val_accuracy: 0.4993
# Epoch 9/50
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3235 - accuracy: 0.5309 - val_loss: 1.3356 - val_accuracy: 0.5313
# Epoch 10/50
# 79/79 [==============================] - 1s 10ms/step - loss: 1.3009 - accuracy: 0.5356 - val_loss: 1.3654 - val_accuracy: 0.5193
# Epoch 11/50
# 79/79 [==============================] - 1s 11ms/step - loss: 1.2661 - accuracy: 0.5531 - val_loss: 1.4696 - val_accuracy: 0.5027
# Epoch 12/50
# 79/79 [==============================] - 1s 12ms/step - loss: 1.2529 - accuracy: 0.5573 - val_loss: 1.3614 - val_accuracy: 0.5345
# Epoch 13/50
# 79/79 [==============================] - 1s 12ms/step - loss: 1.2267 - accuracy: 0.5663 - val_loss: 1.4442 - val_accuracy: 0.5197
# Epoch 14/50
# 79/79 [==============================] - 1s 13ms/step - loss: 1.2072 - accuracy: 0.5708 - val_loss: 1.3310 - val_accuracy: 0.5480
# Epoch 15/50
# 79/79 [==============================] - 1s 12ms/step - loss: 1.1823 - accuracy: 0.5817 - val_loss: 1.3901 - val_accuracy: 0.5270
# Epoch 16/50
# 79/79 [==============================] - 1s 11ms/step - loss: 1.1802 - accuracy: 0.5821 - val_loss: 1.3474 - val_accuracy: 0.5458
# Epoch 17/50
# 79/79 [==============================] - 1s 11ms/step - loss: 1.1522 - accuracy: 0.5944 - val_loss: 1.2323 - val_accuracy: 0.5800
# Epoch 18/50
# 79/79 [==============================] - 1s 11ms/step - loss: 1.1350 - accuracy: 0.6005 - val_loss: 1.2741 - val_accuracy: 0.5720
# Epoch 19/50
# 79/79 [==============================] - 1s 11ms/step - loss: 1.1087 - accuracy: 0.6097 - val_loss: 1.2716 - val_accuracy: 0.5715
# Epoch 20/50
# 79/79 [==============================] - 1s 12ms/step - loss: 1.0977 - accuracy: 0.6131 - val_loss: 1.2096 - val_accuracy: 0.5954
# Epoch 21/50
# 79/79 [==============================] - 1s 10ms/step - loss: 1.0818 - accuracy: 0.6187 - val_loss: 1.2435 - val_accuracy: 0.5804
# Epoch 22/50
# 79/79 [==============================] - 1s 11ms/step - loss: 1.0815 - accuracy: 0.6162 - val_loss: 1.2364 - val_accuracy: 0.5884
# Epoch 23/50
# 79/79 [==============================] - 1s 12ms/step - loss: 1.0497 - accuracy: 0.6306 - val_loss: 1.3388 - val_accuracy: 0.5602
# Epoch 24/50
# 79/79 [==============================] - 1s 12ms/step - loss: 1.0431 - accuracy: 0.6319 - val_loss: 1.2154 - val_accuracy: 0.5980
# Epoch 25/50
# 79/79 [==============================] - 1s 11ms/step - loss: 1.0179 - accuracy: 0.6428 - val_loss: 1.2234 - val_accuracy: 0.6010
# Epoch 26/50
# 79/79 [==============================] - 1s 12ms/step - loss: 1.0103 - accuracy: 0.6459 - val_loss: 1.3912 - val_accuracy: 0.5605
# Epoch 27/50
# 79/79 [==============================] - 1s 13ms/step - loss: 1.0137 - accuracy: 0.6446 - val_loss: 1.1968 - val_accuracy: 0.6106
# Epoch 28/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.9853 - accuracy: 0.6524 - val_loss: 1.1993 - val_accuracy: 0.6065
# Epoch 29/50
# 79/79 [==============================] - 1s 11ms/step - loss: 0.9692 - accuracy: 0.6626 - val_loss: 1.1945 - val_accuracy: 0.6083
# Epoch 30/50
# 79/79 [==============================] - 1s 10ms/step - loss: 0.9492 - accuracy: 0.6669 - val_loss: 1.2470 - val_accuracy: 0.6021
# Epoch 31/50
# 79/79 [==============================] - 1s 11ms/step - loss: 0.9498 - accuracy: 0.6637 - val_loss: 1.2099 - val_accuracy: 0.6118
# Epoch 32/50
# 79/79 [==============================] - 1s 11ms/step - loss: 0.9371 - accuracy: 0.6741 - val_loss: 1.2910 - val_accuracy: 0.5994
# Epoch 33/50
# 79/79 [==============================] - 1s 11ms/step - loss: 0.9225 - accuracy: 0.6773 - val_loss: 1.2422 - val_accuracy: 0.6075
# Epoch 34/50
# 79/79 [==============================] - 1s 11ms/step - loss: 0.9090 - accuracy: 0.6829 - val_loss: 1.2609 - val_accuracy: 0.5966
# Epoch 35/50
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8950 - accuracy: 0.6879 - val_loss: 1.3386 - val_accuracy: 0.5941
# Epoch 36/50
# 79/79 [==============================] - 1s 11ms/step - loss: 0.8978 - accuracy: 0.6848 - val_loss: 1.3051 - val_accuracy: 0.6004
# Epoch 37/50
# 79/79 [==============================] - 1s 11ms/step - loss: 0.8855 - accuracy: 0.6896 - val_loss: 1.2350 - val_accuracy: 0.6211
# Epoch 38/50
# 79/79 [==============================] - 1s 11ms/step - loss: 0.8718 - accuracy: 0.6951 - val_loss: 1.1793 - val_accuracy: 0.6295
# Epoch 39/50
# 79/79 [==============================] - 1s 10ms/step - loss: 0.8580 - accuracy: 0.6993 - val_loss: 1.3655 - val_accuracy: 0.5910
# Epoch 40/50
# 79/79 [==============================] - 1s 12ms/step - loss: 0.8621 - accuracy: 0.7002 - val_loss: 1.2321 - val_accuracy: 0.6192
# Epoch 41/50
# 79/79 [==============================] - 1s 12ms/step - loss: 0.8492 - accuracy: 0.7010 - val_loss: 1.1821 - val_accuracy: 0.6314
# Epoch 42/50
# 79/79 [==============================] - 1s 12ms/step - loss: 0.8231 - accuracy: 0.7115 - val_loss: 1.2337 - val_accuracy: 0.6187
# Epoch 43/50
# 79/79 [==============================] - 1s 12ms/step - loss: 0.8256 - accuracy: 0.7100 - val_loss: 1.5871 - val_accuracy: 0.5690
# Epoch 44/50
# 79/79 [==============================] - 1s 11ms/step - loss: 0.8351 - accuracy: 0.7077 - val_loss: 1.2072 - val_accuracy: 0.6303
# Epoch 45/50
# 79/79 [==============================] - 1s 11ms/step - loss: 0.8135 - accuracy: 0.7141 - val_loss: 1.2025 - val_accuracy: 0.6282
# Epoch 46/50
# 79/79 [==============================] - 1s 11ms/step - loss: 0.8080 - accuracy: 0.7178 - val_loss: 1.2151 - val_accuracy: 0.6167
# Epoch 47/50
# 79/79 [==============================] - 1s 11ms/step - loss: 0.7942 - accuracy: 0.7236 - val_loss: 1.1277 - val_accuracy: 0.6474
# Epoch 48/50
# 79/79 [==============================] - 1s 11ms/step - loss: 0.7857 - accuracy: 0.7256 - val_loss: 1.2239 - val_accuracy: 0.6252
# Epoch 49/50
# 79/79 [==============================] - 1s 10ms/step - loss: 0.7902 - accuracy: 0.7249 - val_loss: 1.3774 - val_accuracy: 0.6038
# Epoch 50/50
# 79/79 [==============================] - 1s 11ms/step - loss: 0.7741 - accuracy: 0.7293 - val_loss: 1.2200 - val_accuracy: 0.6370

# %%
def plot_losses(history):
    plt.rcParams['figure.figsize'] = [20, 5]
    f, (ax1, ax2) = plt.subplots(1, 2, sharex=True)

    ax1.set_title('Losses')
    ax1.set_xlabel('epoch')
    ax1.set_ylabel('loss')
    ax1.legend(loc="upper right")
    ax1.grid()
    ax1.plot(history['loss'], label='Training loss')
    ax1.plot(history['val_loss'], label='Validation loss')
    ax1.legend()

    ax2.set_title('Accuracy')
    ax2.set_xlabel('epoch')
    ax2.set_ylabel('acc')
    ax2.legend(loc="upper right")
    ax2.grid()
    ax2.plot(history['accuracy'], label='Training accuracy')
    ax2.plot(history['val_accuracy'], label='Validation accuracy')
    ax2.legend()

    plt.show()

# %%
plot_losses(history.history)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ---
#
# Creado por **Guillermo Iglesias** (guillermo.iglesias@upm.es)
#
# <img src="https://licensebuttons.net/l/by-nc-sa/3.0/88x31.png">
