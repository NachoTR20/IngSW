# %% [markdown]
# # Imports

# %%
import numpy as np

from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelBinarizer

from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # Load dataset

# %%
(trainX, trainY), (testX, testY) = mnist.load_data()

trainX = trainX / 255.0
testX = testX / 255.0

train_labels = trainY
test_labels = testY

trainY = LabelBinarizer().fit_transform(trainY)
testY = LabelBinarizer().fit_transform(testY)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
print("Train X dataset shape: ", np.shape(trainX))
print("Train y dataset shape: ", np.shape(trainY))
print("Test X dataset shape: ", np.shape(testX))
print("Test y dataset shape: ", np.shape(testY))
# Out:
# Train X dataset shape:  (60000, 28, 28)
# Train y dataset shape:  (60000, 10)
# Test X dataset shape:  (10000, 28, 28)
# Test y dataset shape:  (10000, 10)

# %%
def show_examples(X, y_real, y_pred):
    fig, ax = plt.subplots(1, 5, figsize=[25, 5])

    for i, img in enumerate(X[:5]):
        ax[i].imshow(img, cmap='Greys')
        ax[i].set_title('y real: ' + str(y_real[i]) +
                        '\ny predicted: ' + str(y_pred[i]))
    plt.show()

# %%
show_examples(trainX, train_labels, train_labels)

# %% [markdown]
# # Model definition

# %%
def create_classifier():
    input = Input(shape=(28, 28, 1))

    x = Conv2D(filters=16, kernel_size=(3,3), padding='same', activation='relu')(input)
    x = MaxPooling2D()(x)
    x = Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu')(x)
    x = MaxPooling2D()(x)

    x = Flatten()(x)

    output = Dense(10, activation='softmax')(x)

    return Model(input, output)

# %%
model = create_classifier()
model.summary()
#plot_model(model, show_shapes=True, show_layer_names=False)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 16)        160
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dense (Dense)               (None, 10)                15690
#
# =================================================================
# Total params: 20490 (80.04 KB)
# Trainable params: 20490 (80.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Train model

# %%
history = model.fit(trainX, trainY, epochs=20, batch_size=128, validation_data=(testX, testY), verbose=1)
# Out:
# Epoch 1/20
# 469/469 [==============================] - 14s 6ms/step - loss: 0.2993 - accuracy: 0.9141 - val_loss: 0.1120 - val_accuracy: 0.9640
# Epoch 2/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0896 - accuracy: 0.9724 - val_loss: 0.0645 - val_accuracy: 0.9791
# Epoch 3/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0642 - accuracy: 0.9811 - val_loss: 0.0503 - val_accuracy: 0.9831
# Epoch 4/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0529 - accuracy: 0.9842 - val_loss: 0.0452 - val_accuracy: 0.9849
# Epoch 5/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0446 - accuracy: 0.9867 - val_loss: 0.0460 - val_accuracy: 0.9842
# Epoch 6/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0392 - accuracy: 0.9883 - val_loss: 0.0368 - val_accuracy: 0.9874
# Epoch 7/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0350 - accuracy: 0.9894 - val_loss: 0.0395 - val_accuracy: 0.9869
# Epoch 8/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0315 - accuracy: 0.9905 - val_loss: 0.0461 - val_accuracy: 0.9834
# Epoch 9/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0293 - accuracy: 0.9912 - val_loss: 0.0325 - val_accuracy: 0.9894
# Epoch 10/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0271 - accuracy: 0.9917 - val_loss: 0.0318 - val_accuracy: 0.9891
# Epoch 11/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0246 - accuracy: 0.9931 - val_loss: 0.0320 - val_accuracy: 0.9892
# Epoch 12/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0228 - accuracy: 0.9936 - val_loss: 0.0362 - val_accuracy: 0.9889
# Epoch 13/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0213 - accuracy: 0.9937 - val_loss: 0.0342 - val_accuracy: 0.9893
# Epoch 14/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0193 - accuracy: 0.9944 - val_loss: 0.0308 - val_accuracy: 0.9899
# Epoch 15/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0184 - accuracy: 0.9949 - val_loss: 0.0313 - val_accuracy: 0.9905
# Epoch 16/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0169 - accuracy: 0.9950 - val_loss: 0.0366 - val_accuracy: 0.9892
# Epoch 17/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0160 - accuracy: 0.9954 - val_loss: 0.0349 - val_accuracy: 0.9887
# Epoch 18/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.0371 - val_accuracy: 0.9901
# Epoch 19/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0135 - accuracy: 0.9961 - val_loss: 0.0347 - val_accuracy: 0.9899
# Epoch 20/20
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0130 - accuracy: 0.9961 - val_loss: 0.0346 - val_accuracy: 0.9902

# %% [markdown]
# # Evaluate the model

# %%
def plot_losses(history):
    plt.rcParams['figure.figsize'] = [20, 5]
    f, (ax1, ax2) = plt.subplots(1, 2, sharex=True)

    ax1.set_title('Losses')
    ax1.set_xlabel('epoch')
    ax1.legend(loc="upper right")
    ax1.grid()
    ax1.plot(history['loss'], label='Training loss')
    ax1.plot(history['val_loss'], label='Validation loss')
    ax1.legend()

    ax2.set_title('Accuracy')
    ax2.set_xlabel('epoch')
    ax2.legend(loc="upper right")
    ax2.grid()
    ax2.plot(history['accuracy'], label='Training accuracy')
    ax2.plot(history['val_accuracy'], label='Validation accuracy')
    ax2.legend()

    plt.show()

# %%
plot_losses(history.history)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
y_pred = model.predict(testX[:5]).argmax(axis=-1)

show_examples(testX[:5], test_labels[:5], y_pred)
# Out:
# 1/1 [==============================] - 0s 133ms/step

# %% [markdown]
# ---
#
# Creado por **Guillermo Iglesias** (guillermo.iglesias@upm.es)
#
# <img src="https://licensebuttons.net/l/by-nc-sa/3.0/88x31.png">
